# %%
import pandas as pd

df = pd.DataFrame({"price": [100, 200, 300]})
df.head()
df.describe()
# Out:
#        price
# count    3.0
# mean   200.0
# std    100.0
# min    100.0
# 25%    150.0
# 50%    200.0
# 75%    250.0
# max    300.0

# %%
df.info
# Out:
# <bound method DataFrame.info of    price
# 0    100
# 1    200
# 2    300>
